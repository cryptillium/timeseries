# %%
import numpy as np
import pandas as pd

# %matplotlib inline

from sklearn.metrics import mean_squared_error
from pathlib import Path
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Regression Analysis: Seasonal Effects with Sklearn Linear Regression
# In this notebook, you will build a SKLearn linear regression model to predict Yen futures ("settle") returns with *lagged* Yen futures returns.

# %%
# Futures contract on the Yen-dollar exchange rate:
# This is the continuous chain of the futures contracts that are 1 month to expiration
yen_futures = pd.read_csv(
    Path("./data/yen.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 1976-08-02  3398.0  3401.0  3398.0  3401.0     NaN  3401.0     2.0
# 1976-08-03  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-04  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-05  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-06  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
#
#             Previous Day Open Interest
# Date
# 1976-08-02                         1.0
# 1976-08-03                         1.0
# 1976-08-04                         1.0
# 1976-08-05                         1.0
# 1976-08-06                         1.0

# %%
# Trim the dataset to begin on January 1st, 1990
yen_futures = yen_futures.loc["1990-01-01":, :]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1990-01-02  6954.0  6954.0  6835.0  6847.0     NaN  6847.0  48336.0
# 1990-01-03  6877.0  6910.0  6865.0  6887.0     NaN  6887.0  38206.0
# 1990-01-04  6937.0  7030.0  6924.0  7008.0     NaN  7008.0  49649.0
# 1990-01-05  6952.0  6985.0  6942.0  6950.0     NaN  6950.0  29944.0
# 1990-01-08  6936.0  6972.0  6936.0  6959.0     NaN  6959.0  19763.0
#
#             Previous Day Open Interest
# Date
# 1990-01-02                     51473.0
# 1990-01-03                     53860.0
# 1990-01-04                     55699.0
# 1990-01-05                     53111.0
# 1990-01-08                     52072.0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Returns

# %%
# Create a series using "Settle" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s

# multiply % change
yen_futures['Return'] = yen_futures['Settle'].pct_change() * 100

# clean the data
yen_futures = yen_futures.replace(-np.inf, np.nan)
yen_futures = yen_futures.dropna()
yen_futures.tail()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2019-10-09  9381.0  9391.5  9330.5  9343.5    38.5  9338.0   99153.0
# 2019-10-10  9343.5  9380.5  9293.5  9301.0    34.5  9303.5  159397.0
# 2019-10-11  9308.5  9309.0  9240.0  9267.0    52.5  9251.0  158810.0
# 2019-10-14  9259.0  9292.0  9250.5  9261.0    14.0  9265.0   69457.0
# 2019-10-15  9264.5  9280.0  9216.5  9220.0    43.5  9221.5  108342.0
#
#             Previous Day Open Interest    Return
# Date
# 2019-10-09                    145470.0 -0.410601
# 2019-10-10                    144474.0 -0.369458
# 2019-10-11                    147471.0 -0.564304
# 2019-10-14                    153902.0  0.151335
# 2019-10-15                    151564.0 -0.469509

# %% [markdown]
# ### Lagged Returns

# %%
# Create a lagged return using the shift function
yen_futures['Lagged_Return'] = yen_futures['Return'].shift(1)
yen_futures.dropna(inplace=True)
yen_futures.tail()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2019-10-09  9381.0  9391.5  9330.5  9343.5    38.5  9338.0   99153.0
# 2019-10-10  9343.5  9380.5  9293.5  9301.0    34.5  9303.5  159397.0
# 2019-10-11  9308.5  9309.0  9240.0  9267.0    52.5  9251.0  158810.0
# 2019-10-14  9259.0  9292.0  9250.5  9261.0    14.0  9265.0   69457.0
# 2019-10-15  9264.5  9280.0  9216.5  9220.0    43.5  9221.5  108342.0
#
#             Previous Day Open Interest    Return  Lagged_Return
# Date
# 2019-10-09                    145470.0 -0.410601       0.170931
# 2019-10-10                    144474.0 -0.369458      -0.410601
# 2019-10-11                    147471.0 -0.564304      -0.369458
# 2019-10-14                    153902.0  0.151335      -0.564304
# 2019-10-15                    151564.0 -0.469509       0.151335

# %% [markdown]
# ### Train Test Split

# %%
# Create a train/test split for the data using 2018-2019 for testing and the rest for training
train = yen_futures[:'2018']
test = yen_futures['2019':]

# %%
# Create four dataframes:
# X_train (training set using just the independent variables), X_test (test set of of just the independent variables)
# Y_train (training set using just the "y" variable, i.e., "Futures Return"), Y_test (test set of just the "y" variable):

X_train = train['Lagged_Return'].to_frame()
X_test = test['Lagged_Return'].to_frame()
Y_train = train['Return']
Y_test = test['Return']

# %%
X_train
# Out:
#             Lagged_Return
# Date
# 2014-02-19      -0.427829
# 2014-02-20      -0.020460
# 2014-02-21       0.020465
# 2014-02-24      -0.204604
# 2014-02-25       0.020502
# ...                   ...
# 2018-12-24      -0.187545
# 2018-12-26       0.834485
# 2018-12-27      -0.893346
# 2018-12-28       0.464525
# 2018-12-31       0.297242
#
# [1218 rows x 1 columns]

# %% [markdown]
# # Linear Regression Model

# %%
# Create a Linear Regression model and fit it to the training data
model = LinearRegression()

# Fit a SKLearn linear regression using just the training set (X_train, Y_train):
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Make predictions using the Testing Data
#
# Note: We want to evaluate the model using data that it has never seen before, in this case: X_test.

# %%
# Make a prediction of "y" values using just the test dataset
y_predict = model.predict(X_test)
print(y_predict)
# Out:
# [-1.01932139e-02 -7.90534246e-03 -1.68816355e-02  3.35416899e-03
#  -2.78355217e-03 -3.20626695e-03 -6.91381457e-03 -2.09892128e-03
#  -2.94243380e-03 -6.32873327e-03 -2.52229811e-04 -6.10921667e-04
#  -2.82492417e-04  1.06218984e-03 -8.02218009e-03 -8.02544626e-04
#  -2.55936969e-03 -4.11119498e-03 -6.14523372e-03 -4.27012926e-03
#  -6.67125499e-03 -3.89556568e-03  2.06203353e-03  9.16192698e-06
#  -3.09195934e-03 -3.62900914e-03 -4.65013362e-03 -4.11227431e-03
#   1.84495725e-03 -2.60332247e-03  6.93749312e-04 -7.91605387e-03
#  -3.89890889e-03 -1.79177412e-03 -2.00464890e-03 -4.92992705e-03
#  -3.41196871e-03  2.71745605e-04 -9.17619616e-03  1.07694926e-03
#  -2.58614106e-04  1.71689377e-03 -5.93135024e-03 -2.26007098e-03
#  -4.39512287e-03 -5.87307552e-03 -7.67118358e-03 -2.21355259e-03
#  -3.19228235e-03 -5.75464858e-03  2.73747328e-03 -5.81867527e-03
#  -3.24556365e-03 -1.16649555e-02 -1.05700994e-02 -2.22872474e-03
# ...

# %%
# Assemble actual y data (Y_test) with predicted y data (from just above) into two columns in a dataframe:
out_of_sample = Y_test.to_frame()
out_of_sample['Predicted Return'] = y_predict
out_of_sample
# Out:
#               Return  Predicted Return
# Date
# 2019-01-02  0.430705         -0.010193
# 2019-01-03  1.346290         -0.007905
# 2019-01-04 -0.717767         -0.016882
# 2019-01-07 -0.091718          0.003354
# 2019-01-08 -0.048601         -0.002784
# ...              ...               ...
# 2019-10-09 -0.410601         -0.005359
# 2019-10-10 -0.369458          0.000343
# 2019-10-11 -0.564304         -0.000061
# 2019-10-14  0.151335          0.001850
# 2019-10-15 -0.469509         -0.005166
#
# [196 rows x 2 columns]

# %%
# Plot the first 20 predictions vs the true values
out_of_sample.iloc[:20].plot(title='Actual vs. Predicted -- first 20 predictions', subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %% [markdown]
# # Out-of-Sample Performance
#
# Evaluate the model using "out-of-sample" data (X_test and y_test)

# %%
# Calculate the mean_squared_error (MSE) on actual versus predicted test "y" 
mse = mean_squared_error(out_of_sample['Return'], out_of_sample['Predicted Return'])


# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):
rmse = np.sqrt(mse)
print(f"Out-of-Sample Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Out-of-Sample Root Mean Squared Error (RMSE): 0.39649005208597526

# %% [markdown]
# # In-Sample Performance
#
# Evaluate the model using in-sample data (X_train and y_train)

# %%
# Construct a dataframe using just the "y" training data:
in_sample = Y_train.to_frame()

# Add a column of "in-sample" predictions to that dataframe:  
in_sample['Predicted Return'] = model.predict(X_train)


# Plotting the first 20 predictions vs the true values (in sample data)
in_sample.iloc[:20].plot(title='Actual vs. Predicted -- first 20 predictions ( == in sample data ==)', subplots=True)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
mse = mean_squared_error(in_sample['Return'], in_sample['Predicted Return'])

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
rmse = np.sqrt(mse)
print(f"In-Sample Root Mean Squared Error (RMSE): {rmse}")
# Out:
# In-Sample Root Mean Squared Error (RMSE): 0.5658708047560468

# %% [markdown]
# # Conclusions

# %% [markdown]
# **Root Mean Square Error (RMSE)** is a standard way to measure the error of a model in predicting quantitative data.
# The RMSE is the square root of the variance of the residuals. It indicates the absolute fit of the model to the data and
# how close the observed data points are to the model’s predicted values.
#
# RMSE can be interpreted as the standard deviation of the unexplained variance, and has the useful property of being in
# the same units as the response variable. Lower values of RMSE indicate better fit. RMSE is a good measure of how accurately the model
# predicts the response, and it is the most important criterion for fit if the main purpose of the model is prediction. The best measure of model fit depends on the researcher’s objectives.
#
# Based on this, the results indicates that the out of sample performance have a better fit and predicted values than that of the 'in-sample' data points.
# Also, as you can see from the chart, as more and more data points are added, the predicted values become closer and closer to the true data set.
